# %%
import pandas as pd
from pandas import read_csv
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
df = pd.read_csv('/content/gdrive/My Drive/jumlah_kasus_hiv_jabar.csv')

# %%
df = pd.read_csv('/content/jumlah_kasus_hiv_jabar.csv')

# %%
df
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0      1             32    JAWA BARAT                 3201
# 1      2             32    JAWA BARAT                 3201
# 2      3             32    JAWA BARAT                 3201
# 3      4             32    JAWA BARAT                 3201
# 4      5             32    JAWA BARAT                 3201
# ..   ...            ...           ...                  ...
# 966  967             32    JAWA BARAT                 3279
# 967  968             32    JAWA BARAT                 3279
# 968  969             32    JAWA BARAT                 3279
# 969  970             32    JAWA BARAT                 3279
# 970  971             32    JAWA BARAT                 3279
#
#     nama_kabupaten_kota kelompok_umur jenis_kelamin  jumlah_kasus satuan  \
# 0       KABUPATEN BOGOR           0-4     LAKI-LAKI             4  ORANG
# 1       KABUPATEN BOGOR           0-4     PEREMPUAN             7  ORANG
# ...

# %%
df.style.hide_index()
# Out:
# <ipython-input-20-046e9c3a6dbb>:1: FutureWarning: this method is deprecated in favour of `Styler.hide(axis="index")`
#   df.style.hide_index()
# <style type="text/css">
# </style>
# <table id="T_12f44" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_12f44_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_12f44_level0_col1" class="col_heading level0 col1" >kode_provinsi</th>
#       <th id="T_12f44_level0_col2" class="col_heading level0 col2" >nama_provinsi</th>
#       <th id="T_12f44_level0_col3" class="col_heading level0 col3" >kode_kabupaten_kota</th>
#       <th id="T_12f44_level0_col4" class="col_heading level0 col4" >nama_kabupaten_kota</th>
#       <th id="T_12f44_level0_col5" class="col_heading level0 col5" >kelompok_umur</th>
#       <th id="T_12f44_level0_col6" class="col_heading level0 col6" >jenis_kelamin</th>
#       <th id="T_12f44_level0_col7" class="col_heading level0 col7" >jumlah_kasus</th>
# ...

# %% [markdown]
# # Cek Null

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 971 entries, 0 to 970
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   971 non-null    int64
#  1   kode_provinsi        971 non-null    int64
#  2   nama_provinsi        971 non-null    object
#  3   kode_kabupaten_kota  971 non-null    int64
#  4   nama_kabupaten_kota  971 non-null    object
#  5   kelompok_umur        971 non-null    object
#  6   jenis_kelamin        971 non-null    object
#  7   jumlah_kasus         971 non-null    int64
#  8   satuan               971 non-null    object
#  9   tahun                971 non-null    int64
# dtypes: int64(5), object(5)
# memory usage: 76.0+ KB

# %%
df.isnull().sum()
# Out:
# id                     0
# kode_provinsi          0
# nama_provinsi          0
# kode_kabupaten_kota    0
# nama_kabupaten_kota    0
# kelompok_umur          0
# jenis_kelamin          0
# jumlah_kasus           0
# satuan                 0
# tahun                  0
# dtype: int64

# %% [markdown]
# # Cek data duplikat

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 966    False
# 967    False
# 968    False
# 969    False
# 970    False
# Length: 971, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Penghapusan kolom id

# %%
df = df.drop('id', axis=1)

# %%
df
# Out:
#      kode_provinsi nama_provinsi  kode_kabupaten_kota nama_kabupaten_kota  \
# 0               32    JAWA BARAT                 3201     KABUPATEN BOGOR
# 1               32    JAWA BARAT                 3201     KABUPATEN BOGOR
# 2               32    JAWA BARAT                 3201     KABUPATEN BOGOR
# 3               32    JAWA BARAT                 3201     KABUPATEN BOGOR
# 4               32    JAWA BARAT                 3201     KABUPATEN BOGOR
# ..             ...           ...                  ...                 ...
# 966             32    JAWA BARAT                 3279         KOTA BANJAR
# 967             32    JAWA BARAT                 3279         KOTA BANJAR
# 968             32    JAWA BARAT                 3279         KOTA BANJAR
# 969             32    JAWA BARAT                 3279         KOTA BANJAR
# 970             32    JAWA BARAT                 3279         KOTA BANJAR
#
#     kelompok_umur jenis_kelamin  jumlah_kasus satuan  tahun
# ...

# %% [markdown]
# # Menghapus kolom kode_provinsi

# %%
df = df.drop('kode_provinsi', axis=1)

# %%
df
# Out:
#     nama_provinsi  kode_kabupaten_kota nama_kabupaten_kota kelompok_umur  \
# 0      JAWA BARAT                 3201     KABUPATEN BOGOR           0-4
# 1      JAWA BARAT                 3201     KABUPATEN BOGOR           0-4
# 2      JAWA BARAT                 3201     KABUPATEN BOGOR          5-14
# 3      JAWA BARAT                 3201     KABUPATEN BOGOR          5-14
# 4      JAWA BARAT                 3201     KABUPATEN BOGOR         15-19
# ..            ...                  ...                 ...           ...
# 966    JAWA BARAT                 3279         KOTA BANJAR         20-24
# 967    JAWA BARAT                 3279         KOTA BANJAR         25-49
# 968    JAWA BARAT                 3279         KOTA BANJAR         25-49
# 969    JAWA BARAT                 3279         KOTA BANJAR           ≥50
# 970    JAWA BARAT                 3279         KOTA BANJAR           ≥50
#
#     jenis_kelamin  jumlah_kasus satuan  tahun
# ...

# %% [markdown]
# # Menghapus kolom kode kabupaten dan kota

# %%
df = df.drop('kode_kabupaten_kota', axis=1)

# %%
df
# Out:
#     nama_provinsi nama_kabupaten_kota kelompok_umur jenis_kelamin  \
# 0      JAWA BARAT     KABUPATEN BOGOR           0-4     LAKI-LAKI
# 1      JAWA BARAT     KABUPATEN BOGOR           0-4     PEREMPUAN
# 2      JAWA BARAT     KABUPATEN BOGOR          5-14     LAKI-LAKI
# 3      JAWA BARAT     KABUPATEN BOGOR          5-14     PEREMPUAN
# 4      JAWA BARAT     KABUPATEN BOGOR         15-19     LAKI-LAKI
# ..            ...                 ...           ...           ...
# 966    JAWA BARAT         KOTA BANJAR         20-24     PEREMPUAN
# 967    JAWA BARAT         KOTA BANJAR         25-49     LAKI-LAKI
# 968    JAWA BARAT         KOTA BANJAR         25-49     PEREMPUAN
# 969    JAWA BARAT         KOTA BANJAR           ≥50     LAKI-LAKI
# 970    JAWA BARAT         KOTA BANJAR           ≥50     PEREMPUAN
#
#      jumlah_kasus satuan  tahun
# 0               4  ORANG   2019
# 1               7  ORANG   2019
# 2               3  ORANG   2019
# 3               0  ORANG   2019
# ...

# %% [markdown]
# # Menghapus kolom satuan

# %%
df = df.drop('satuan', axis=1)

# %%
df
# Out:
#     nama_provinsi nama_kabupaten_kota kelompok_umur jenis_kelamin  \
# 0      JAWA BARAT     KABUPATEN BOGOR           0-4     LAKI-LAKI
# 1      JAWA BARAT     KABUPATEN BOGOR           0-4     PEREMPUAN
# 2      JAWA BARAT     KABUPATEN BOGOR          5-14     LAKI-LAKI
# 3      JAWA BARAT     KABUPATEN BOGOR          5-14     PEREMPUAN
# 4      JAWA BARAT     KABUPATEN BOGOR         15-19     LAKI-LAKI
# ..            ...                 ...           ...           ...
# 966    JAWA BARAT         KOTA BANJAR         20-24     PEREMPUAN
# 967    JAWA BARAT         KOTA BANJAR         25-49     LAKI-LAKI
# 968    JAWA BARAT         KOTA BANJAR         25-49     PEREMPUAN
# 969    JAWA BARAT         KOTA BANJAR           ≥50     LAKI-LAKI
# 970    JAWA BARAT         KOTA BANJAR           ≥50     PEREMPUAN
#
#      jumlah_kasus  tahun
# 0               4   2019
# 1               7   2019
# 2               3   2019
# 3               0   2019
# 4               8   2019
# ...

# %% [markdown]
# # Mengubah nama kolom

# %%
df.columns = df.columns.str.replace('_', ' ')

# %%
df
# Out:
#     nama provinsi nama kabupaten kota kelompok umur jenis kelamin  \
# 0      JAWA BARAT     KABUPATEN BOGOR           0-4     LAKI-LAKI
# 1      JAWA BARAT     KABUPATEN BOGOR           0-4     PEREMPUAN
# 2      JAWA BARAT     KABUPATEN BOGOR          5-14     LAKI-LAKI
# 3      JAWA BARAT     KABUPATEN BOGOR          5-14     PEREMPUAN
# 4      JAWA BARAT     KABUPATEN BOGOR         15-19     LAKI-LAKI
# ..            ...                 ...           ...           ...
# 966    JAWA BARAT         KOTA BANJAR         20-24     PEREMPUAN
# 967    JAWA BARAT         KOTA BANJAR         25-49     LAKI-LAKI
# 968    JAWA BARAT         KOTA BANJAR         25-49     PEREMPUAN
# 969    JAWA BARAT         KOTA BANJAR           ≥50     LAKI-LAKI
# 970    JAWA BARAT         KOTA BANJAR           ≥50     PEREMPUAN
#
#      jumlah kasus  tahun
# 0               4   2019
# 1               7   2019
# 2               3   2019
# 3               0   2019
# 4               8   2019
# ...

# %% [markdown]
# # Mengubah awal kata menjadi kapital

# %%
df.columns = df.columns.str.title()

# %%
df
# Out:
#     Nama Provinsi Nama Kabupaten Kota Kelompok Umur Jenis Kelamin  \
# 0      JAWA BARAT     KABUPATEN BOGOR           0-4     LAKI-LAKI
# 1      JAWA BARAT     KABUPATEN BOGOR           0-4     PEREMPUAN
# 2      JAWA BARAT     KABUPATEN BOGOR          5-14     LAKI-LAKI
# 3      JAWA BARAT     KABUPATEN BOGOR          5-14     PEREMPUAN
# 4      JAWA BARAT     KABUPATEN BOGOR         15-19     LAKI-LAKI
# ..            ...                 ...           ...           ...
# 966    JAWA BARAT         KOTA BANJAR         20-24     PEREMPUAN
# 967    JAWA BARAT         KOTA BANJAR         25-49     LAKI-LAKI
# 968    JAWA BARAT         KOTA BANJAR         25-49     PEREMPUAN
# 969    JAWA BARAT         KOTA BANJAR           ≥50     LAKI-LAKI
# 970    JAWA BARAT         KOTA BANJAR           ≥50     PEREMPUAN
#
#      Jumlah Kasus  Tahun
# 0               4   2019
# 1               7   2019
# 2               3   2019
# 3               0   2019
# 4               8   2019
# ...

# %% [markdown]
# # Export data kedalam format csv

# %%
from google.colab import files

df.to_csv('Kasus_HIV_Jabar.csv', index=False, encoding = 'utf-8-sig')
files.download('Kasus_HIV_Jabar.csv')
